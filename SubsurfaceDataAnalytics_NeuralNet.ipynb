# %% [markdown]
# <p align="center">
#     <img src="https://github.com/GeostatsGuy/GeostatsPy/blob/master/TCG_color_logo.png?raw=true" width="220" height="240" />
#
# </p>
#
# ## Subsurface Data Analytics
#
# ## Artificial Neural Networks for Prediction in Python
#
# #### Michael Pyrcz, Associate Professor, University of Texas at Austin
#
# ##### [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1) | [GeostatsPy](https://github.com/GeostatsGuy/GeostatsPy)
#
# #### Honggeun Jo, Graduate Student, The University of Texas at Austin
#
# ##### [LinkedIn](https://www.linkedin.com/in/honggeun-jo/?originalSubdomain=kr) | [Twitter](https://twitter.com/HonggeunJ)
#
# #### Wen Pan, Graduate Student, The University of Texas at Austin
#
# #### Eduardo Maldonado-Cruz, Graduate Student, The University of Texas at Austin
#
#
# ### PGE 383 Exercise: Artificial Neural Networks for Subsurface Modeling in Python
#
# Here's a simple workflow, demonstration of artificial neural networks for subsurface modeling workflows. This should help you get started with building subsurface models that use data analytics and machine learning. Here's some basic details about neural networks.
#
# #### Neural Networks
#
# Machine learning method for supervised learning for classification and regression analysis.  Here are some key aspects of support vector machines.
#
# **Basic Design** *"...a computing system made up of a number of simple, highly interconnected processing elements, which process information by their dynamic state response to external inputs."* Caudill (1989).
#
# **Nature-inspire Computing** based on the neuronal structure in the brain, including many interconnected simple, processing units, known as nodes that are capable of complicated emergent pattern detection due to a large number of nodes and interconnectivity.
#
# **Training and Testing** just like and other predictive model (e.g. linear regression, decision trees and support vector machines) we perform training to fit parameters and testing to tune hyperparameters.  Here we observe the error with training and testing datasets, but do not demonstrate tuning of the hyperparameters.
#
# **Parameters** are the weights applied to each connection and a bias term applied to each node.  For a single node in an artificial neural network, this includes the slope terms, $\beta_i$, and the bias term, $\beta_{0}$.
#
# \begin{equation}
# Y = \sum_{i=1}^m \beta_i X + \beta_0
# \end{equation}
#
# it can be seen that the number of parameters increases rapidly as we increase the number of nodes and the connectivity between the nodes.
#
# **Layers** the typical artificial neural net is structured with an **input layer**, with one node for each $m$ predictor feature, $X_1,\ldots,X_m$. There is an **ouput layer**, with one node for each $r$ response feature, $Y_1,\ldots,Y_r$.  There may be one or more layers of nodes between the input and output layers, known as **hidden layer(s)**.
#
# **Connections** are the linkages between the nodes in adjacent layers.  For example, in a fully connected artificial neural network, all the input nodes are connected to all of the nodes in the first layer, then all of the nodes in the first layer are connected to the next layer and so forth. Each connection includes a weight parameter as indicated above.
#
# **Nodes** receive the weighted signal from the connected previous layer nodes, sum and then apply this result to the **activation** function in the node. Some example activation functions include:
#
# * **Binary** the node fires or not.  This is represented by a Heaviside step function.
#
# * **Identify** the input is passed to the output $f(x) = x$
#
# * **Linear** the node passes a signal that increases linearly with the weighted input.
#
# * **Logistic** also known as sigmoid or soft step $f(x) = \frac{1}{1+e^{-x}}$
#
# the node output is the nonlinear activiation function applied to the linearly weighted inputs. This is fed to all nodes in the next layer.
#
# **Training Cycles** - the presentation of a batch of data, forward application of the current prediction model to make estimates, calculation of error and then backpropagation of error to correct the artificial neural network parameters to reduce the error over all of the batches.
#
# **Batch** is the set of training data for each training cycle of forward prediction and back propagation of error, drawn to train for each iteration. There is a trade-off, a larger batch results in more computational time per iteration, but a more accurate estimate of the error to adjust the weights.  Smaller batches result in a nosier estimate of the error, but faster epochs, this results in faster learning and even possibly more robust models.
#
# **Epochs** - is a set of training cycles, batches covering all available training data.
#
# **Local Minimums** - if one calculated the error hypersurface over the range of model parameters it would be hyparabolic, there is a global minimium error solution.  But this error hyper surface is rough and it is possible to be stuck in a local minimum. **Learning Rate** and **Mommentum** coefficients are introduced to avoid getting stuck in local minimums.
#
# * **Mommentum** is a hyperparameter to control the use of information from the weight update over the last epoch for consideration in the current epoch.  This can be accomplished with an update vector, $v_i$, a mommentum parameter, $\alpha$, to calculate the current weight update, $v_{i+1}$ given the new update $\theta_{i+1}$.
#
# \begin{equation}
# v_{i+1} = \alpha v_i + \theta_{i+1}
# \end{equation}
#
# * **Learning Rate** is a hyperparameter that controls the adjustment of the weights in response to the gradient indicated by backpropagation of error
#
# ##### Applications to subsurface modeling
#
# We demonstrate the estimation of normal score transformed porosity from depth.  This would be useful for building a vertical trend model.
#
# * modeling the complicated relationship between porosity and depth.
#
# #### Limitations of Neural Network Estimation
#
# Since we demonstrate the use of an artificial neural network to estimate porosity from sparsely sampled data over depth, we should comment on limitations of our artificial neural networks for this estimation problem:
#
# * does not honor the well data
#
# * does not honor the histogram of the data
#
# * does not honor spatial correlation
#
# * does not honor the multivariate relationship
#
# * generally low interpretability models
#
# * requires a large number of data for effective training
#
# * high model complexity with high model variance
#
#
# #### Workflow Goals
#
# Learn the basics of machine learning in python to predict subsurface features. This includes:
#
# * Loading and visualizing sample data
# * Trying out neural nets
#
# #### Objective
#
# In the PGE 383: Subsurface Machine Learning Class, I want to provide hands-on experience with building subsurface modeling workflows. Python provides an excellent vehicle to accomplish this. I have coded a package called GeostatsPy with GSLIB: Geostatistical Library (Deutsch and Journel, 1998) functionality that provides basic building blocks for building subsurface modeling workflows.
#
# The objective is to remove the hurdles of subsurface modeling workflow construction by providing building blocks and sufficient examples. This is not a coding class per se, but we need the ability to 'script' workflows working with numerical methods.
#
# #### Getting Started
#
# Here's the steps to get setup in Python with the GeostatsPy package:
#
# 1. Install Anaconda 3 on your machine (https://www.anaconda.com/download/).
# 2. From Anaconda Navigator (within Anaconda3 group), go to the environment tab, click on base (root) green arrow and open a terminal.
# 3. In the terminal type: pip install geostatspy.
# 4. Open Jupyter and in the top block get started by copy and pasting the code block below from this Jupyter Notebook to start using the geostatspy functionality.
#
# You will need to copy the data file to your working directory.  They are available here:
#
# * Tabular data - 12_sample_data.csv found [here](https://github.com/GeostatsGuy/GeoDataSets/blob/master/12_sample_data.csv).
#
# There are exampled below with these functions. You can go here to see a list of the available functions, https://git.io/fh4eX, other example workflows and source code.
#
# #### Import Required Packages
#
# We will also need some standard packages. These should have been installed with Anaconda 3.

# %%
import numpy as np                        # ndarrys for gridded data
import pandas as pd                       # DataFrames for tabular data
import os                                 # set working directory, run executables
import matplotlib.pyplot as plt           # for plotting
import seaborn as sns                     # for plotting
import warnings                           # supress warnings from seaborn pairplot
from sklearn.model_selection import train_test_split # train / test DatFrame split

# %% [markdown]
# We will also need the following packages to train and test our artificial neural nets:
#
# * Tensorflow - open source machine learning, with Keras modulw - high level application programing interface (API) to build and train models
#
# More information is available at [tensorflow install](https://www.tensorflow.org/install).
#
# * This workflow was designed with tensorflow version > 2.0.
#
# To import Tensorflow, set memory growth and check your current version of tensorflow you could run the next block of code.

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

physical_devices = tf.config.list_physical_devices('GPU')

#tf.config.experimental.set_memory_growth(physical_devices[0], True)
print('TensorFlow version = ' + tf.__version__)                         # check the installed version of tensorflow

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
device_lib.list_local_devices()
# Out:
# TensorFlow version = 2.15.0
# Num GPUs Available:  0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8879671121579194657
#  xla_global_id: -1]

# %% [markdown]
# Let's import all of the tensorflow and keras methods that we will need in our workflow.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential  
from tensorflow.keras.layers import Dense, Activation, Dropout  
#from keras.models import Sequential, load_model
#from keras.layers.core import Dense, Dropout, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras import backend as k

# %% [markdown]
# #### Set the working directory
#
# I always like to do this so I don't lose files and to simplify subsequent read and writes (avoid including the full address each time).

# %%
#os.chdir("c:/PGE383")

# %% [markdown]
# #### Loading Data
# Let's load the provided multivariate, spatial dataset '12_sample_data.csv'.  It is a comma delimited file with:
#
# * Depth ($m$)
# * Normal Score Porosity
#
# It is common to transform properties to standard normal for geostatistical workflows.
#
# We load it with the pandas 'read_csv' function into a data frame we called 'df' and then preview it to make sure it loaded correctly.
#
# **Python Tip: using functions from a package** just type the label for the package that we declared at the beginning:
#
# ```python
# import pandas as pd
# ```
#
# so we can access the pandas function 'read_csv' with the command:
#
# ```python
# pd.read_csv()
# ```
#
# but read csv has required input parameters. The essential one is the name of the file. For our circumstance all the other default parameters are fine. If you want to see all the possible parameters for this function, just go to the docs [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
#
# * The docs are always helpful
# * There is often a lot of flexibility for Python functions, possible through using various inputs parameters
#
# also, the program has an output, a pandas DataFrame loaded from the data.  So we have to specficy the name / variable representing that new object.
#
# ```python
# df = pd.read_csv("1D_Porosity.csv")
# ```
#
# Let's run this command to load the data and then look at the resulting DataFrame to ensure that we loaded it.

# %%
#df2 = pd.read_csv("1D_Porosity.csv")                    # read a .csv file in as a DataFrame  
df2 = pd.read_csv("https://raw.githubusercontent.com/GeostatsGuy/GeoDataSets/master/1D_Porosity.csv") # load the data from Dr. Pyrcz's github repository
df2.head()                                              # we could also use this command for a table preview
# Out:
#    Depth  Nporosity
# 0   0.25      -1.37
# 1   0.50      -2.08
# 2   0.75      -1.67
# 3   1.00      -1.16
# 4   1.25      -0.24

# %% [markdown]
# #### Data Normalization
#
# We must normalize the features before we apply them in an artificial neural network model. These are the motivations for this normalization:
#
# * remove impact of scale of different types of data (i.e., depth varies between $[0,10]$, but porosity only varies between $[-3,3.0]$).
#
# * activation functions in artificial neural networks are designed to be more sensive to values of nodes closer to 0.0 (i.e., results in higher gradient and improves backpropagation in training)
#
# Let's normalize each feature.
#
# * We apply the min max normalization by-hand to force both the predictor and response features to be bound $[-1,1]$.
#
# * It is easy to backtransform given we keep track of the original min and max values

# %%
depth_min = df2['Depth'].values.min(); depth_max = df2['Depth'].values.max()
Npor_min = df2['Nporosity'].values.min(); Npor_max = df2['Nporosity'].values.max()
df2['norm_Depth'] = (df2['Depth'] - depth_min)/(depth_max - depth_min) * 2 - 1
df2['norm_Nporosity'] = (df2['Nporosity'] - Npor_min)/(Npor_max - Npor_min) * 2 - 1
df2.head()
# Out:
#    Depth  Nporosity  norm_Depth  norm_Nporosity
# 0   0.25      -1.37   -1.000000       -0.679458
# 1   0.50      -2.08   -0.948718       -1.000000
# 2   0.75      -1.67   -0.897436       -0.814898
# 3   1.00      -1.16   -0.846154       -0.584650
# 4   1.25      -0.24   -0.794872       -0.169300

# %% [markdown]
# It is also a good idea to check the summary statistics.
#
# * All normalized features should now range from -1.0 to 1.0

# %%
df2.describe().transpose()
# Out:
#                 count      mean       std   min       25%           50%  \
# Depth            40.0  5.125000  2.922613  0.25  2.687500  5.125000e+00
# Nporosity        40.0  0.022250  0.992111 -2.08 -0.757500  1.400000e-01
# norm_Depth       40.0  0.000000  0.599510 -1.00 -0.500000 -5.551115e-17
# norm_Nporosity   40.0 -0.050903  0.447906 -1.00 -0.402935  2.257336e-03
#
#                      75%    max
# Depth           7.562500  10.00
# Nporosity       0.742500   2.35
# norm_Depth      0.500000   1.00
# norm_Nporosity  0.274266   1.00

# %% [markdown]
# #### Separation of Training and Testing Data
#
# We also need to split our data into training / testing datasets so that we:
#
# * can train our artificial neural networks using the training data
#
# * while testing their performance with the withheld testing (validation) data.

# %%
X2 = df2.iloc[:,[0,2]]                        # extract the predictor feature - acoustic impedance
y2 = df2.iloc[:,[1,3]]                        # extract the response feature - porosity
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=73073)

# %% [markdown]
# #### Visualize the Dataset
#
# Let's visualize the train and test data split on a single scatter plot.
#
# * we want to make sure it is fair
#
# * ensure that the test samples are not clustered or too far away from the training data.
#
# We will look at the original data and normalized data, the input to the neural network.

# %%
plt.subplot(211)
plt.plot(X2_train['Depth'].values,y2_train['Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=0.4, label = "Train")
plt.plot(X2_test['Depth'].values,y2_test['Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=0.4, label = "Test")
plt.title('Standard Normal Porosity vs. Depth')
plt.xlabel('Z (m)')
plt.ylabel('NPorosity')
plt.legend()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=1.0, wspace=0.2, hspace=0.2)

plt.subplot(212)
plt.plot(X2_train['norm_Depth'].values,y2_train['norm_Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=0.4, label = "Train")
plt.plot(X2_test['norm_Depth'].values,y2_test['norm_Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=0.4, label = "Test")
plt.title('Normalized Standard Normal Porosity vs. Normalized Depth')
plt.xlabel('Normalized Z')
plt.ylabel('Normalized NPorosity')
plt.legend()

plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=1.5, wspace=0.2, hspace=0.3)
plt.show()

# %% [markdown]
# #### Specify the Prediction Locations
#
# Given this training and testing data, let's specify the prediction locations over the range of the observed depths at regularly spaced $nbins$ locations.

# %%
# Specify the prediction locations
nbins = 1000
depth_bins = np.linspace(depth_min, depth_max, nbins) # set the bins for prediction
norm_depth_bins = (depth_bins-depth_min)/(depth_max-depth_min)*2-1 # use normalized bins

# %% [markdown]
# #### Build and Train a Simple Neural Network
#
# For our first model we will build a simple model with:
#
# * 1 predictor feature - depth ($d$)
#
# * 1 responce feature - normal score porosity ($N\{\phi\}$)
#
# we will build a model to predict normal score porosity from depth over all locations in our model $\bf{u} \in AOI$.
#
# \begin{equation}
# N\{\phi(\bf{u})\} = \hat{f} (d(\bf{u}))
# \end{equation}
#
# and use this model to support the prediction of porosity between the wells.
#
# #### Design, Train and Test a Neural Network
#
# In the following code we use keras / tensorflow to:
#
# 1. **Design the Network** - we use a fully connected, feed forward neural network with one node in the input and output layers, to receive the normalized depth and output the normalized (normal score) porosity.  We found by trial and error, given the complexity of the dataset, that we required a significant network width (about 500 nodes) and a network depth of atleast 4 hidden layers.
#
#
# 2. **Select the Optimizer** - we selected the adam optimizer (Kingma and Ba, 2015).  This optimizer is computationally efficient and is well suited to problems with noisy data and sparse gradients. It is an extension of stochastic gradient descent with the addition of adaptive gradient algorithm that calculates per-parameter learning rates to improve learning with sparse gradients, and root mean square propopagation that sets the learning rate based on the recent magnitudes of the gradients for each parameter to improve performance with noisy data.  We include stochastic gradient descent for experimentation.
#
#     * we found a learning rate of 0.01 to 0.001 works well
#     * we found the rate of decay parameters of $\beta_1=0.9$ and $\beta_2=0.999$ performed well
#
#
# 3. **Compile the Machine** - specify the optimizer, loss function and the metric for model training.
#
#
# 4. **Train the Network** - fit / train the model parameters over a specified number of batch size within a specified number of epochs.  We specify the train and test normalized predictor and response features.
#
# Then we visualize the model in the original units.

# %%
# Design the neural network
model_2 = Sequential([
    Dense(1, activation='linear', input_shape=(1,)),                  # input layer
    Dense(50, activation='relu'),
    Dense(20, activation='relu'),                                    # uncomment these to add hidden layers
#     Dense(20, activation='relu'),
#     Dense(20, activation='relu'),
#     Dense(20, activation='relu'),
    Dense(1, activation='linear'),                                     # output layer
])

# Select the Optimizer
adam = Adam(learning_rate=0.003, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False,weight_decay=0.0) # adam optimizer
#sgd = keras.optimizers.SGD(lr=0.001, momentum=0.0, decay = 0.0, nesterov=False)  # stochastic gradient descent

# Compile the Machine
model_2.compile(optimizer=adam,loss='mse',metrics=['accuracy'])

# Train the Network
hist_2 = model_2.fit(X2_train['norm_Depth'], y2_train['norm_Nporosity'],
    batch_size=1,epochs=100,validation_data=(X2_test['norm_Depth'], y2_test['norm_Nporosity']),verbose = 0)

# Predict with the Network
pred_norm_Nporsity = model_2.predict(np.array(norm_depth_bins)) # predict with our ANN
pred_Nporosity = ((pred_norm_Nporsity + 1)/2*(Npor_max - Npor_min)+Npor_min)

# Plot the Model Predictions
plt.subplot(1,1,1)
plt.plot(depth_bins,pred_Nporosity,'black',linewidth=2)
plt.plot(X2_train['Depth'].values,y2_train['Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=1.0, label = "Train")
plt.plot(X2_test['Depth'].values,y2_test['Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=1.0, label = "Test")
plt.xlabel('Depth (m)')
plt.ylabel('Porosity (faction)')
plt.legend()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Evaluation of the Model
#
# For my specified artificial neural network design and optimization parameters I have a very flexible model to fit the data.
#
# * artificial neural networks live up to their designation as **Universal Function Approximators**
#
# Let's check the training curve, loss functions for our model over training and testing datasets.
#
# * **square loss** ($L_2$ loss) is the:
#
# \begin{equation}
# L_2 = \sum_{\bf{u}_{\alpha} \in AOI} \left(y(\bf{u}_{\alpha}) - \hat{f}(x_1(\bf{u}_{\alpha}),\ldots,x_m(\bf{u}_{\alpha})\right)
# \end{equation}
#
# * this is a measure of the inaccuracy over the available data
#
# We can see the progress of the model over epochs in reduction of training and testing error.
#
# * we can observe that the model matches the training data after about 200 epochs, but continues to improve up the 1,000 epochs

# %%
# Plot the Loss vs. Training Epoch 
plt.subplot(1,1,1)
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Loss function of Artificial Neural Net Example #2')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0,0.4)
plt.grid()
plt.tight_layout()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# #### Some Observations
#
# We performed a set of experiments and made the following observations that may help you experiment with the design and training of this artificial neural network. Each machine was trained over 1000 epochs with a batch size of 5.
#
# For a 1 $\times$ 100 $\times$ 100 $\times$ 1 neural network:
# * Learning Rate of 0.001 still converging at 1000 epochs, missing some features
# * Learning Rate of 0.1 - stuck in a local minum as a step function
#
# For a 1 $\times$ 500 $\times$ 500 $\times$ 1 neural network:
# * Learning Rate of 0.01 - 0.001 for a close fit to training data
# * Learning Rate of 0.1 - stuck in a local minimum as a line
# * Learning Rate of $\le$ 0.0001 still converging at 1000 epochs, missing some features
#
# For a 1 $\times$ 500 $\times$ 500 $\times$ 500 $\times$ 1 neural network:
# * Learning Rate of 0.01 - 0.001 for a close fit to training data
# * Learning Rate of 0.1 - stuck as a line
# * Learning Rate of $\le$ 0.0001 still converging at 1000 epochs, missing some features
#
# #### Visualizing the Neural Net
#
# There are some methods available to interogate the artificial neural net.
#
# * neural net summary
#
# * weights
#
# Here's the summary from our neural net.  It lists by layers the number of nodes and number of parameters.

# %%
model_2.summary()                                      # artificial neural network design and number of parameters
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 1)                 2
#
#  dense_25 (Dense)            (None, 50)                100
#
#  dense_26 (Dense)            (None, 20)                1020
#
#  dense_27 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1143 (4.46 KB)
# Trainable params: 1143 (4.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# We can also see the actual trained weights for each node in each layer.

# %%
for layer in model_2.layers:                            # weights for the trained artificial neural network
    g = layer.get_config()
    h = layer.get_weights()
    print(g)
    print(h)
    print('\n')
# Out:
# {'name': 'dense_24', 'trainable': True, 'dtype': 'float32', 'batch_input_shape': (None, 1), 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# [array([[-1.4043294]], dtype=float32), array([-0.01696865], dtype=float32)]
#
#
# {'name': 'dense_25', 'trainable': True, 'dtype': 'float32', 'units': 50, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# [array([[
#          1.79827020e-01, -8.56022984e-02,  6.66510165e-02,
#         -3.10379982e-01,  2.68198371e-01, -1.45162761e-01,
#         -4.53246534e-02,  4.09790501e-02,  1.63191423e-01,
#          1.23406962e-01, -1.68741912e-01, -2.10874394e-01,
#         -1.31611317e-01,  1.81804895e-01],
#        [-1.54123247e-01, -2.02361673e-01, -2.88481385e-01,
#          2.58919477e-01,  2.35189363e-01,  2.42118120e-01,
#          1.99987784e-01,  2.48930454e-01,  6.08016253e-02,
#         -1.86786503e-01,  1.97339654e-01, -2.86188126e-01,
#          2.09350258e-01, -9.62732881e-02, -2.34750420e-01,
#          4.68904153e-02, -6.98335022e-02,  7.20841289e-02,
#         -1.72471955e-01,  1.52208775e-01],
#        [-3.08158100e-01, -7.11123765e-01, -1.59177870e-01,
#          1.47526547e-01,  1.30413775e-03,  2.70785093e-01,
#         -2.38774136e-01,  1.67400032e-01, -1.74008295e-01,
#         -8.27931762e-02, -2.77931690e-01, -2.04250455e-01,
#          1.71153650e-01,  1.65247396e-01,  3.11515421e-01,
#          1.46004200e-01,  8.42643976e-02, -1.02291284e-02,
#         -1.24127693e-01,  1.37606010e-01],
#        [-2.73390681e-01, -1.22035846e-01,  1.44260168e-01,
#         -3.20467442e-01, -2.50887394e-01, -1.43908173e-01,
#          1.69213906e-01,  5.22355624e-02, -1.32176531e-02,
#         -1.89866871e-01, -4.36717495e-02, -1.39149562e-01,
#          6.01087585e-02,  1.45176575e-01,  3.28095853e-02,
#          6.29729126e-03, -1.00016922e-01, -1.83639526e-02,
#         -4.64965850e-02,  1.52482629e-01]], dtype=float32), array([-0.01423108,  0.05393384,  0.01871619,  0.2659612 ,  0.01359454,
#        -0.0551761 , -0.01184886, -0.04410643, -0.02292506, -0.01852811,
#        -0.09147067,  0.1975556 , -0.01969641, -0.10398123, -0.11266836,
#        -0.0514115 ,  0.03364913, -0.06698554,  0.03486611, -0.05188895],
#       dtype=float32)]
#
#
# {'name': 'dense_27', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# [array([[ 0.3555193 ],
#        [-0.3305721 ],
#        [ 0.61828625],
#        [ 0.69412845],
#        [-0.03357228],
#        [ 0.0042168 ],
#        [ 0.4435677 ],
#        [ 0.12028697],
#        [ 0.11956017],
#        [-0.37038764],
#        [-0.04149689],
#        [ 0.30977562],
#        [ 0.36433482],
#        [-0.0077534 ],
#        [-0.12951793],
#        [ 0.3742582 ],
#        [ 0.21320345],
#        [-0.2347037 ],
#        [-0.46487674],
#        [-0.31416157]], dtype=float32), array([-0.04168117], dtype=float32)]

# %% [markdown]
# #### Overfit Artificial Neural Network
#
# Let's slow down the learning rate, decrease the learning rate decay and increase the number of Epochs.

# %%
model_3 = Sequential([
    Dense(100, activation='linear', input_shape=(1,)),                  # input layer
    Dense(50, activation='relu'),
    Dense(50, activation='relu'),
    Dense(50, activation='relu'), 
#     Dense(20, activation='relu'),                                    # uncomment these to add hidden layers
#     Dense(20, activation='relu'),
#     Dense(20, activation='relu'),
#     Dense(20, activation='relu'),
    Dense(1, activation='tanh'),                                     # output layer
])


adam = Adam(learning_rate=0.0001) # adam optimizer
#sgd = keras.optimizers.SGD(lr=0.001, momentum=0.0, decay = 0.0, nesterov=False)  # stochastic gradient descent

# Compile the Machine
model_3.compile(optimizer=adam,loss='mse',metrics=['accuracy'])

# Train the Network
hist3 = model_3.fit(X2_train['norm_Depth'].values, y2_train['norm_Nporosity'].values,
    batch_size=5, epochs=20000,validation_data=(X2_test['norm_Depth'], y2_test['norm_Nporosity']))
# Out:
# Epoch 1/20000
# 7/7 [==============================] - 1s 38ms/step - loss: 0.2197 - accuracy: 0.0000e+00 - val_loss: 0.0624 - val_accuracy: 0.0000e+00
# Epoch 2/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2163 - accuracy: 0.0000e+00 - val_loss: 0.0614 - val_accuracy: 0.0000e+00
# Epoch 3/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2134 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 4/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2108 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 5/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2084 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 6/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2061 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 7/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2048 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 8/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2028 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 9/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2011 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 10/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1998 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 11/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1978 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 12/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1965 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 13/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1949 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 14/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1931 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 15/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1913 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 16/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1900 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 17/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1882 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 18/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1871 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 19/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1853 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 20/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1846 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 21/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 22/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1818 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 23/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1812 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 24/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1797 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 25/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1785 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 26/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1777 - accuracy: 0.0000e+00 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 27/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1768 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 28/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1756 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 29/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1749 - accuracy: 0.0000e+00 - val_loss: 0.0607 - val_accuracy: 0.0000e+00
# Epoch 30/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1734 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 31/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1728 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 32/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1715 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 33/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1708 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 34/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1697 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 35/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1690 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 36/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1684 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 37/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1673 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 38/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1664 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 39/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1655 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 40/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 41/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1634 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 42/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1625 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 43/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1617 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 44/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1605 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 45/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1600 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 46/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1592 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 47/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1580 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 48/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1571 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 49/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1562 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 50/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1558 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 51/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1547 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 52/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1539 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 53/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1533 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 54/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1521 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 55/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1510 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 56/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1503 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 57/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1491 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 58/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 59/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1470 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 60/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1462 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 61/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1452 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 62/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1442 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 63/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1439 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 64/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1422 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 65/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1415 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 66/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1398 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 67/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1390 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 68/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 69/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1381 - accuracy: 0.0000e+00 - val_loss: 0.0560 - val_accuracy: 0.0000e+00
# Epoch 70/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1361 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 71/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 72/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1342 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 73/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 74/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1324 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 75/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 76/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1306 - accuracy: 0.0000e+00 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 77/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1295 - accuracy: 0.0000e+00 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 78/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1286 - accuracy: 0.0000e+00 - val_loss: 0.0615 - val_accuracy: 0.0000e+00
# Epoch 79/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1281 - accuracy: 0.0000e+00 - val_loss: 0.0622 - val_accuracy: 0.0000e+00
# Epoch 80/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 81/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1259 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 82/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1250 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 83/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 84/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1228 - accuracy: 0.0000e+00 - val_loss: 0.0605 - val_accuracy: 0.0000e+00
# Epoch 85/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1218 - accuracy: 0.0000e+00 - val_loss: 0.0617 - val_accuracy: 0.0000e+00
# Epoch 86/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1212 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 87/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1197 - accuracy: 0.0000e+00 - val_loss: 0.0614 - val_accuracy: 0.0000e+00
# Epoch 88/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1187 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 89/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1179 - accuracy: 0.0000e+00 - val_loss: 0.0605 - val_accuracy: 0.0000e+00
# Epoch 90/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1173 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 91/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 92/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 93/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1156 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 94/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1142 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 95/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1133 - accuracy: 0.0000e+00 - val_loss: 0.0607 - val_accuracy: 0.0000e+00
# Epoch 96/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1123 - accuracy: 0.0000e+00 - val_loss: 0.0610 - val_accuracy: 0.0000e+00
# Epoch 97/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1112 - accuracy: 0.0000e+00 - val_loss: 0.0615 - val_accuracy: 0.0000e+00
# Epoch 98/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1101 - accuracy: 0.0000e+00 - val_loss: 0.0628 - val_accuracy: 0.0000e+00
# Epoch 99/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1099 - accuracy: 0.0000e+00 - val_loss: 0.0638 - val_accuracy: 0.0000e+00
# Epoch 100/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1089 - accuracy: 0.0000e+00 - val_loss: 0.0633 - val_accuracy: 0.0000e+00
# Epoch 101/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1077 - accuracy: 0.0000e+00 - val_loss: 0.0631 - val_accuracy: 0.0000e+00
# Epoch 102/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1083 - accuracy: 0.0000e+00 - val_loss: 0.0643 - val_accuracy: 0.0000e+00
# Epoch 103/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1071 - accuracy: 0.0000e+00 - val_loss: 0.0632 - val_accuracy: 0.0000e+00
# Epoch 104/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1061 - accuracy: 0.0000e+00 - val_loss: 0.0633 - val_accuracy: 0.0000e+00
# Epoch 105/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1065 - accuracy: 0.0000e+00 - val_loss: 0.0621 - val_accuracy: 0.0000e+00
# Epoch 106/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1049 - accuracy: 0.0000e+00 - val_loss: 0.0621 - val_accuracy: 0.0000e+00
# Epoch 107/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1041 - accuracy: 0.0000e+00 - val_loss: 0.0625 - val_accuracy: 0.0000e+00
# Epoch 108/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1034 - accuracy: 0.0000e+00 - val_loss: 0.0630 - val_accuracy: 0.0000e+00
# Epoch 109/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1029 - accuracy: 0.0000e+00 - val_loss: 0.0626 - val_accuracy: 0.0000e+00
# Epoch 110/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1020 - accuracy: 0.0000e+00 - val_loss: 0.0631 - val_accuracy: 0.0000e+00
# Epoch 111/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1016 - accuracy: 0.0000e+00 - val_loss: 0.0641 - val_accuracy: 0.0000e+00
# Epoch 112/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1006 - accuracy: 0.0000e+00 - val_loss: 0.0639 - val_accuracy: 0.0000e+00
# Epoch 113/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0999 - accuracy: 0.0000e+00 - val_loss: 0.0648 - val_accuracy: 0.0000e+00
# Epoch 114/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0997 - accuracy: 0.0000e+00 - val_loss: 0.0655 - val_accuracy: 0.0000e+00
# Epoch 115/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0989 - accuracy: 0.0000e+00 - val_loss: 0.0658 - val_accuracy: 0.0000e+00
# Epoch 116/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0982 - accuracy: 0.0000e+00 - val_loss: 0.0647 - val_accuracy: 0.0000e+00
# Epoch 117/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0979 - accuracy: 0.0000e+00 - val_loss: 0.0648 - val_accuracy: 0.0000e+00
# Epoch 118/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0973 - accuracy: 0.0000e+00 - val_loss: 0.0653 - val_accuracy: 0.0000e+00
# Epoch 119/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0964 - accuracy: 0.0000e+00 - val_loss: 0.0652 - val_accuracy: 0.0000e+00
# Epoch 120/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0960 - accuracy: 0.0000e+00 - val_loss: 0.0650 - val_accuracy: 0.0000e+00
# Epoch 121/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0956 - accuracy: 0.0000e+00 - val_loss: 0.0651 - val_accuracy: 0.0000e+00
# Epoch 122/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0951 - accuracy: 0.0000e+00 - val_loss: 0.0649 - val_accuracy: 0.0000e+00
# Epoch 123/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0943 - accuracy: 0.0000e+00 - val_loss: 0.0656 - val_accuracy: 0.0000e+00
# Epoch 124/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0938 - accuracy: 0.0000e+00 - val_loss: 0.0662 - val_accuracy: 0.0000e+00
# Epoch 125/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0940 - accuracy: 0.0000e+00 - val_loss: 0.0657 - val_accuracy: 0.0000e+00
# Epoch 126/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0929 - accuracy: 0.0000e+00 - val_loss: 0.0669 - val_accuracy: 0.0000e+00
# Epoch 127/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0922 - accuracy: 0.0000e+00 - val_loss: 0.0675 - val_accuracy: 0.0000e+00
# Epoch 128/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0918 - accuracy: 0.0000e+00 - val_loss: 0.0673 - val_accuracy: 0.0000e+00
# Epoch 129/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0913 - accuracy: 0.0000e+00 - val_loss: 0.0674 - val_accuracy: 0.0000e+00
# Epoch 130/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0908 - accuracy: 0.0000e+00 - val_loss: 0.0672 - val_accuracy: 0.0000e+00
# Epoch 131/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0901 - accuracy: 0.0000e+00 - val_loss: 0.0662 - val_accuracy: 0.0000e+00
# Epoch 132/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0899 - accuracy: 0.0000e+00 - val_loss: 0.0659 - val_accuracy: 0.0000e+00
# Epoch 133/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0898 - accuracy: 0.0000e+00 - val_loss: 0.0660 - val_accuracy: 0.0000e+00
# Epoch 134/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0895 - accuracy: 0.0000e+00 - val_loss: 0.0664 - val_accuracy: 0.0000e+00
# Epoch 135/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0899 - accuracy: 0.0000e+00 - val_loss: 0.0667 - val_accuracy: 0.0000e+00
# Epoch 136/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0878 - accuracy: 0.0000e+00 - val_loss: 0.0679 - val_accuracy: 0.0000e+00
# Epoch 137/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0882 - accuracy: 0.0000e+00 - val_loss: 0.0686 - val_accuracy: 0.0000e+00
# Epoch 138/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0885 - accuracy: 0.0000e+00 - val_loss: 0.0697 - val_accuracy: 0.0000e+00
# Epoch 139/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0872 - accuracy: 0.0000e+00 - val_loss: 0.0694 - val_accuracy: 0.0000e+00
# Epoch 140/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0874 - accuracy: 0.0000e+00 - val_loss: 0.0689 - val_accuracy: 0.0000e+00
# Epoch 141/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0863 - accuracy: 0.0000e+00 - val_loss: 0.0697 - val_accuracy: 0.0000e+00
# Epoch 142/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0861 - accuracy: 0.0000e+00 - val_loss: 0.0698 - val_accuracy: 0.0000e+00
# Epoch 143/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0853 - accuracy: 0.0000e+00 - val_loss: 0.0701 - val_accuracy: 0.0000e+00
# Epoch 144/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0853 - accuracy: 0.0000e+00 - val_loss: 0.0703 - val_accuracy: 0.0000e+00
# Epoch 145/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0852 - accuracy: 0.0000e+00 - val_loss: 0.0699 - val_accuracy: 0.0000e+00
# Epoch 146/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0852 - accuracy: 0.0000e+00 - val_loss: 0.0695 - val_accuracy: 0.0000e+00
# Epoch 147/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0853 - accuracy: 0.0000e+00 - val_loss: 0.0712 - val_accuracy: 0.0000e+00
# Epoch 148/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0844 - accuracy: 0.0000e+00 - val_loss: 0.0712 - val_accuracy: 0.0000e+00
# Epoch 149/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0835 - accuracy: 0.0000e+00 - val_loss: 0.0708 - val_accuracy: 0.0000e+00
# Epoch 150/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0837 - accuracy: 0.0000e+00 - val_loss: 0.0703 - val_accuracy: 0.0000e+00
# Epoch 151/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0829 - accuracy: 0.0000e+00 - val_loss: 0.0702 - val_accuracy: 0.0000e+00
# Epoch 152/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0834 - accuracy: 0.0000e+00 - val_loss: 0.0703 - val_accuracy: 0.0000e+00
# Epoch 153/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0827 - accuracy: 0.0000e+00 - val_loss: 0.0710 - val_accuracy: 0.0000e+00
# Epoch 154/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 155/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0819 - accuracy: 0.0000e+00 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 156/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0817 - accuracy: 0.0000e+00 - val_loss: 0.0718 - val_accuracy: 0.0000e+00
# Epoch 157/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0816 - accuracy: 0.0000e+00 - val_loss: 0.0723 - val_accuracy: 0.0000e+00
# Epoch 158/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0807 - accuracy: 0.0000e+00 - val_loss: 0.0723 - val_accuracy: 0.0000e+00
# Epoch 159/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0812 - accuracy: 0.0000e+00 - val_loss: 0.0730 - val_accuracy: 0.0000e+00
# Epoch 160/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0808 - accuracy: 0.0000e+00 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 161/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0807 - accuracy: 0.0000e+00 - val_loss: 0.0746 - val_accuracy: 0.0000e+00
# Epoch 162/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0804 - accuracy: 0.0000e+00 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 163/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.0000e+00 - val_loss: 0.0732 - val_accuracy: 0.0000e+00
# Epoch 164/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0796 - accuracy: 0.0000e+00 - val_loss: 0.0730 - val_accuracy: 0.0000e+00
# Epoch 165/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0794 - accuracy: 0.0000e+00 - val_loss: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 166/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0790 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 167/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0797 - accuracy: 0.0000e+00 - val_loss: 0.0717 - val_accuracy: 0.0000e+00
# Epoch 168/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0793 - accuracy: 0.0000e+00 - val_loss: 0.0716 - val_accuracy: 0.0000e+00
# Epoch 169/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.0000e+00 - val_loss: 0.0724 - val_accuracy: 0.0000e+00
# Epoch 170/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0787 - accuracy: 0.0000e+00 - val_loss: 0.0733 - val_accuracy: 0.0000e+00
# Epoch 171/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0783 - accuracy: 0.0000e+00 - val_loss: 0.0735 - val_accuracy: 0.0000e+00
# Epoch 172/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.0000e+00 - val_loss: 0.0738 - val_accuracy: 0.0000e+00
# Epoch 173/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0780 - accuracy: 0.0000e+00 - val_loss: 0.0748 - val_accuracy: 0.0000e+00
# Epoch 174/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0780 - accuracy: 0.0000e+00 - val_loss: 0.0751 - val_accuracy: 0.0000e+00
# Epoch 175/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0779 - accuracy: 0.0000e+00 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 176/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0784 - accuracy: 0.0000e+00 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 177/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0782 - accuracy: 0.0000e+00 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 178/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0782 - accuracy: 0.0000e+00 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 179/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0774 - accuracy: 0.0000e+00 - val_loss: 0.0747 - val_accuracy: 0.0000e+00
# Epoch 180/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.0000e+00 - val_loss: 0.0759 - val_accuracy: 0.0000e+00
# Epoch 181/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.0000e+00 - val_loss: 0.0760 - val_accuracy: 0.0000e+00
# Epoch 182/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0773 - accuracy: 0.0000e+00 - val_loss: 0.0759 - val_accuracy: 0.0000e+00
# Epoch 183/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.0000e+00 - val_loss: 0.0758 - val_accuracy: 0.0000e+00
# Epoch 184/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.0000e+00 - val_loss: 0.0750 - val_accuracy: 0.0000e+00
# Epoch 185/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0767 - accuracy: 0.0000e+00 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 186/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0770 - accuracy: 0.0000e+00 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 187/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0767 - accuracy: 0.0000e+00 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 188/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.0000e+00 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 189/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0761 - accuracy: 0.0000e+00 - val_loss: 0.0743 - val_accuracy: 0.0000e+00
# Epoch 190/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0765 - accuracy: 0.0000e+00 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 191/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0759 - accuracy: 0.0000e+00 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 192/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.0000e+00 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 193/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0760 - accuracy: 0.0000e+00 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 194/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0758 - accuracy: 0.0000e+00 - val_loss: 0.0747 - val_accuracy: 0.0000e+00
# Epoch 195/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0761 - accuracy: 0.0000e+00 - val_loss: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 196/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.0000e+00 - val_loss: 0.0755 - val_accuracy: 0.0000e+00
# Epoch 197/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.0000e+00 - val_loss: 0.0754 - val_accuracy: 0.0000e+00
# Epoch 198/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.0000e+00 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 199/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.0000e+00 - val_loss: 0.0768 - val_accuracy: 0.0000e+00
# Epoch 200/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0756 - accuracy: 0.0000e+00 - val_loss: 0.0766 - val_accuracy: 0.0000e+00
# Epoch 201/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0752 - accuracy: 0.0000e+00 - val_loss: 0.0767 - val_accuracy: 0.0000e+00
# Epoch 202/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0750 - accuracy: 0.0000e+00 - val_loss: 0.0762 - val_accuracy: 0.0000e+00
# Epoch 203/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0751 - accuracy: 0.0000e+00 - val_loss: 0.0757 - val_accuracy: 0.0000e+00
# Epoch 204/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0752 - accuracy: 0.0000e+00 - val_loss: 0.0759 - val_accuracy: 0.0000e+00
# Epoch 205/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0751 - accuracy: 0.0000e+00 - val_loss: 0.0757 - val_accuracy: 0.0000e+00
# Epoch 206/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.0000e+00 - val_loss: 0.0756 - val_accuracy: 0.0000e+00
# Epoch 207/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.0000e+00 - val_loss: 0.0758 - val_accuracy: 0.0000e+00
# Epoch 208/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.0000e+00 - val_loss: 0.0772 - val_accuracy: 0.0000e+00
# Epoch 209/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0756 - accuracy: 0.0000e+00 - val_loss: 0.0776 - val_accuracy: 0.0000e+00
# Epoch 210/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0750 - accuracy: 0.0000e+00 - val_loss: 0.0767 - val_accuracy: 0.0000e+00
# Epoch 211/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0747 - accuracy: 0.0000e+00 - val_loss: 0.0764 - val_accuracy: 0.0000e+00
# Epoch 212/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.0000e+00 - val_loss: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 213/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 214/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0745 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 215/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0742 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 216/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.0000e+00 - val_loss: 0.0770 - val_accuracy: 0.0000e+00
# Epoch 217/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0746 - accuracy: 0.0000e+00 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 218/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0754 - accuracy: 0.0000e+00 - val_loss: 0.0762 - val_accuracy: 0.0000e+00
# Epoch 219/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.0000e+00 - val_loss: 0.0760 - val_accuracy: 0.0000e+00
# Epoch 220/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0743 - accuracy: 0.0000e+00 - val_loss: 0.0761 - val_accuracy: 0.0000e+00
# Epoch 221/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0741 - accuracy: 0.0000e+00 - val_loss: 0.0766 - val_accuracy: 0.0000e+00
# Epoch 222/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0740 - accuracy: 0.0000e+00 - val_loss: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 223/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0746 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 224/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0741 - accuracy: 0.0000e+00 - val_loss: 0.0785 - val_accuracy: 0.0000e+00
# Epoch 225/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 0.0000e+00 - val_loss: 0.0776 - val_accuracy: 0.0000e+00
# Epoch 226/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0768 - val_accuracy: 0.0000e+00
# Epoch 227/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0742 - accuracy: 0.0000e+00 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 228/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.0000e+00 - val_loss: 0.0764 - val_accuracy: 0.0000e+00
# Epoch 229/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0741 - accuracy: 0.0000e+00 - val_loss: 0.0762 - val_accuracy: 0.0000e+00
# Epoch 230/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 231/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0776 - val_accuracy: 0.0000e+00
# Epoch 232/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.0000e+00 - val_loss: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 233/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0735 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 234/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0731 - accuracy: 0.0000e+00 - val_loss: 0.0775 - val_accuracy: 0.0000e+00
# Epoch 235/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0728 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 236/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0729 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 237/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.0000e+00 - val_loss: 0.0773 - val_accuracy: 0.0000e+00
# Epoch 238/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.0000e+00 - val_loss: 0.0779 - val_accuracy: 0.0000e+00
# Epoch 239/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0731 - accuracy: 0.0000e+00 - val_loss: 0.0776 - val_accuracy: 0.0000e+00
# Epoch 240/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0730 - accuracy: 0.0000e+00 - val_loss: 0.0778 - val_accuracy: 0.0000e+00
# Epoch 241/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0773 - val_accuracy: 0.0000e+00
# Epoch 242/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0768 - val_accuracy: 0.0000e+00
# Epoch 243/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0726 - accuracy: 0.0000e+00 - val_loss: 0.0766 - val_accuracy: 0.0000e+00
# Epoch 244/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0730 - accuracy: 0.0000e+00 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 245/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0728 - accuracy: 0.0000e+00 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 246/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0767 - val_accuracy: 0.0000e+00
# Epoch 247/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 248/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0779 - val_accuracy: 0.0000e+00
# Epoch 249/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0784 - val_accuracy: 0.0000e+00
# Epoch 250/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0725 - accuracy: 0.0000e+00 - val_loss: 0.0782 - val_accuracy: 0.0000e+00
# Epoch 251/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0789 - val_accuracy: 0.0000e+00
# Epoch 252/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0790 - val_accuracy: 0.0000e+00
# Epoch 253/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0789 - val_accuracy: 0.0000e+00
# Epoch 254/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0787 - val_accuracy: 0.0000e+00
# Epoch 255/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0788 - val_accuracy: 0.0000e+00
# Epoch 256/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0718 - accuracy: 0.0000e+00 - val_loss: 0.0784 - val_accuracy: 0.0000e+00
# Epoch 257/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0782 - val_accuracy: 0.0000e+00
# Epoch 258/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0780 - val_accuracy: 0.0000e+00
# Epoch 259/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 260/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0782 - val_accuracy: 0.0000e+00
# Epoch 261/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0718 - accuracy: 0.0000e+00 - val_loss: 0.0783 - val_accuracy: 0.0000e+00
# Epoch 262/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0789 - val_accuracy: 0.0000e+00
# Epoch 263/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0793 - val_accuracy: 0.0000e+00
# Epoch 264/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0718 - accuracy: 0.0000e+00 - val_loss: 0.0796 - val_accuracy: 0.0000e+00
# Epoch 265/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0801 - val_accuracy: 0.0000e+00
# Epoch 266/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 267/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 268/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0803 - val_accuracy: 0.0000e+00
# Epoch 269/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 270/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0719 - accuracy: 0.0000e+00 - val_loss: 0.0809 - val_accuracy: 0.0000e+00
# Epoch 271/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00
# Epoch 272/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0714 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 273/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 274/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0809 - val_accuracy: 0.0000e+00
# Epoch 275/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 276/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0794 - val_accuracy: 0.0000e+00
# Epoch 277/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0793 - val_accuracy: 0.0000e+00
# Epoch 278/20000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0713 - accuracy: 0.0000e+00 - val_loss: 0.0792 - val_accuracy: 0.0000e+00
# Epoch 279/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0713 - accuracy: 0.0000e+00 - val_loss: 0.0790 - val_accuracy: 0.0000e+00
# Epoch 280/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0789 - val_accuracy: 0.0000e+00
# Epoch 281/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0714 - accuracy: 0.0000e+00 - val_loss: 0.0792 - val_accuracy: 0.0000e+00
# Epoch 282/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0796 - val_accuracy: 0.0000e+00
# Epoch 283/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0710 - accuracy: 0.0000e+00 - val_loss: 0.0803 - val_accuracy: 0.0000e+00
# Epoch 284/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0709 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 285/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0712 - accuracy: 0.0000e+00 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 286/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0712 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 287/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0714 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 288/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0709 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 289/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0803 - val_accuracy: 0.0000e+00
# Epoch 290/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 291/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0707 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 292/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0705 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 293/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0707 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 294/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0712 - accuracy: 0.0000e+00 - val_loss: 0.0799 - val_accuracy: 0.0000e+00
# Epoch 295/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0713 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 296/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 297/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0705 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 298/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0706 - accuracy: 0.0000e+00 - val_loss: 0.0798 - val_accuracy: 0.0000e+00
# Epoch 299/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.0000e+00 - val_loss: 0.0798 - val_accuracy: 0.0000e+00
# Epoch 300/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0796 - val_accuracy: 0.0000e+00
# Epoch 301/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0710 - accuracy: 0.0000e+00 - val_loss: 0.0793 - val_accuracy: 0.0000e+00
# Epoch 302/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0791 - val_accuracy: 0.0000e+00
# Epoch 303/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.0000e+00 - val_loss: 0.0791 - val_accuracy: 0.0000e+00
# Epoch 304/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0792 - val_accuracy: 0.0000e+00
# Epoch 305/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 306/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0707 - accuracy: 0.0000e+00 - val_loss: 0.0801 - val_accuracy: 0.0000e+00
# Epoch 307/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0706 - accuracy: 0.0000e+00 - val_loss: 0.0801 - val_accuracy: 0.0000e+00
# Epoch 308/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0705 - accuracy: 0.0000e+00 - val_loss: 0.0799 - val_accuracy: 0.0000e+00
# Epoch 309/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0705 - accuracy: 0.0000e+00 - val_loss: 0.0801 - val_accuracy: 0.0000e+00
# Epoch 310/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 311/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.0000e+00 - val_loss: 0.0798 - val_accuracy: 0.0000e+00
# Epoch 312/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0705 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 313/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0704 - accuracy: 0.0000e+00 - val_loss: 0.0798 - val_accuracy: 0.0000e+00
# Epoch 314/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0706 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 315/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0702 - accuracy: 0.0000e+00 - val_loss: 0.0810 - val_accuracy: 0.0000e+00
# Epoch 316/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0702 - accuracy: 0.0000e+00 - val_loss: 0.0808 - val_accuracy: 0.0000e+00
# Epoch 317/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0701 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 318/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0698 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 319/20000
# ...
# Epoch 13154/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0932 - val_accuracy: 0.0000e+00
# Epoch 13155/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0940 - val_accuracy: 0.0000e+00
# Epoch 13156/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 0.0312 - val_loss: 0.0948 - val_accuracy: 0.0000e+00
# Epoch 13157/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0944 - val_accuracy: 0.0000e+00
# Epoch 13158/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0950 - val_accuracy: 0.0000e+00
# Epoch 13159/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0941 - val_accuracy: 0.0000e+00
# Epoch 13160/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0950 - val_accuracy: 0.0000e+00
# Epoch 13161/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0947 - val_accuracy: 0.0000e+00
# Epoch 13162/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0944 - val_accuracy: 0.0000e+00
# Epoch 13163/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0952 - val_accuracy: 0.0000e+00
# Epoch 13164/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0028 - accuracy: 0.0312 - val_loss: 0.0959 - val_accuracy: 0.0000e+00
# Epoch 13165/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0895 - val_accuracy: 0.0000e+00
# Epoch 13166/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0996 - val_accuracy: 0.0000e+00
# Epoch 13167/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.0312 - val_loss: 0.0981 - val_accuracy: 0.0000e+00
# Epoch 13168/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0896 - val_accuracy: 0.0000e+00
# Epoch 13169/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.0312 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 13170/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.1001 - val_accuracy: 0.0000e+00
# Epoch 13171/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0953 - val_accuracy: 0.0000e+00
# Epoch 13172/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0918 - val_accuracy: 0.0000e+00
# Epoch 13173/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0931 - val_accuracy: 0.0000e+00
# Epoch 13174/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0959 - val_accuracy: 0.0000e+00
# Epoch 13175/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0953 - val_accuracy: 0.0000e+00
# Epoch 13176/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0932 - val_accuracy: 0.0000e+00
# Epoch 13177/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0924 - val_accuracy: 0.0000e+00
# Epoch 13178/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0956 - val_accuracy: 0.0000e+00
# Epoch 13179/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0972 - val_accuracy: 0.0000e+00
# Epoch 13180/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.0312 - val_loss: 0.0924 - val_accuracy: 0.0000e+00
# Epoch 13181/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.0312 - val_loss: 0.0987 - val_accuracy: 0.0000e+00
# Epoch 13182/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0943 - val_accuracy: 0.0000e+00
# Epoch 13183/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 13184/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0968 - val_accuracy: 0.0000e+00
# Epoch 13185/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.0312 - val_loss: 0.0900 - val_accuracy: 0.0000e+00
# Epoch 13186/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.0312 - val_loss: 0.0951 - val_accuracy: 0.0000e+00
# Epoch 13187/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.0312 - val_loss: 0.1036 - val_accuracy: 0.0000e+00
# Epoch 13188/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.0312 - val_loss: 0.0840 - val_accuracy: 0.0000e+00
# Epoch 13189/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.0312 - val_loss: 0.0985 - val_accuracy: 0.0000e+00
# Epoch 13190/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 0.0312 - val_loss: 0.1004 - val_accuracy: 0.0000e+00
# Epoch 13191/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.0312 - val_loss: 0.0840 - val_accuracy: 0.0000e+00
# Epoch 13192/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.0312 - val_loss: 0.0818 - val_accuracy: 0.0000e+00
# Epoch 13193/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0064 - accuracy: 0.0312 - val_loss: 0.1009 - val_accuracy: 0.0000e+00
# Epoch 13194/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0052 - accuracy: 0.0312 - val_loss: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 13195/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 0.0312 - val_loss: 0.0853 - val_accuracy: 0.0000e+00
# Epoch 13196/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 0.0312 - val_loss: 0.0866 - val_accuracy: 0.0000e+00
# Epoch 13197/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 0.0312 - val_loss: 0.0858 - val_accuracy: 0.0000e+00
# Epoch 13198/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.0312 - val_loss: 0.0904 - val_accuracy: 0.0000e+00
# Epoch 13199/20000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0030 - accuracy: 0.0312 - val_loss: 0.0874 - val_accuracy: 0.0000e+00
# Epoch 13200/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.0312 - val_loss: 0.0913 - val_accuracy: 0.0000e+00
# Epoch 13201/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0881 - val_accuracy: 0.0000e+00
# Epoch 13202/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0863 - val_accuracy: 0.0000e+00
# Epoch 13203/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0905 - val_accuracy: 0.0000e+00
# Epoch 13204/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0879 - val_accuracy: 0.0000e+00
# Epoch 13205/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0882 - val_accuracy: 0.0000e+00
# Epoch 13206/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0902 - val_accuracy: 0.0000e+00
# Epoch 13207/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 0.0312 - val_loss: 0.0862 - val_accuracy: 0.0000e+00
# Epoch 13208/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 0.0312 - val_loss: 0.0913 - val_accuracy: 0.0000e+00
# Epoch 13209/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.0312 - val_loss: 0.0778 - val_accuracy: 0.0000e+00
# Epoch 13210/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 0.0312 - val_loss: 0.0907 - val_accuracy: 0.0000e+00
# Epoch 13211/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0907 - val_accuracy: 0.0000e+00
# Epoch 13212/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0864 - val_accuracy: 0.0000e+00
# Epoch 13213/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0856 - val_accuracy: 0.0000e+00
# Epoch 13214/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0892 - val_accuracy: 0.0000e+00
# Epoch 13215/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0829 - val_accuracy: 0.0000e+00
# Epoch 13216/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0859 - val_accuracy: 0.0000e+00
# Epoch 13217/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0874 - val_accuracy: 0.0000e+00
# Epoch 13218/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0901 - val_accuracy: 0.0000e+00
# Epoch 13219/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0895 - val_accuracy: 0.0000e+00
# Epoch 13220/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 0.0312 - val_loss: 0.0898 - val_accuracy: 0.0000e+00
# Epoch 13221/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0800 - val_accuracy: 0.0000e+00
# Epoch 13222/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.0312 - val_loss: 0.0932 - val_accuracy: 0.0000e+00
# Epoch 13223/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0813 - val_accuracy: 0.0000e+00
# Epoch 13224/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.0312 - val_loss: 0.0858 - val_accuracy: 0.0000e+00
# Epoch 13225/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0914 - val_accuracy: 0.0000e+00
# Epoch 13226/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0875 - val_accuracy: 0.0000e+00
# Epoch 13227/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0891 - val_accuracy: 0.0000e+00
# Epoch 13228/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.0312 - val_loss: 0.0913 - val_accuracy: 0.0000e+00
# Epoch 13229/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0905 - val_accuracy: 0.0000e+00
# Epoch 13230/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0857 - val_accuracy: 0.0000e+00
# Epoch 13231/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0892 - val_accuracy: 0.0000e+00
# Epoch 13232/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0916 - val_accuracy: 0.0000e+00
# Epoch 13233/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0903 - val_accuracy: 0.0000e+00
# Epoch 13234/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0867 - val_accuracy: 0.0000e+00
# Epoch 13235/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0880 - val_accuracy: 0.0000e+00
# Epoch 13236/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0933 - val_accuracy: 0.0000e+00
# Epoch 13237/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0856 - val_accuracy: 0.0000e+00
# Epoch 13238/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0883 - val_accuracy: 0.0000e+00
# Epoch 13239/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0899 - val_accuracy: 0.0000e+00
# Epoch 13240/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0882 - val_accuracy: 0.0000e+00
# Epoch 13241/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 13242/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0905 - val_accuracy: 0.0000e+00
# Epoch 13243/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0899 - val_accuracy: 0.0000e+00
# Epoch 13244/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0907 - val_accuracy: 0.0000e+00
# Epoch 13245/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0875 - val_accuracy: 0.0000e+00
# Epoch 13246/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 13247/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0895 - val_accuracy: 0.0000e+00
# Epoch 13248/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.0312 - val_loss: 0.0935 - val_accuracy: 0.0000e+00
# Epoch 13249/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0862 - val_accuracy: 0.0000e+00
# Epoch 13250/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0897 - val_accuracy: 0.0000e+00
# Epoch 13251/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0935 - val_accuracy: 0.0000e+00
# Epoch 13252/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0930 - val_accuracy: 0.0000e+00
# Epoch 13253/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0852 - val_accuracy: 0.0000e+00
# Epoch 13254/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.0312 - val_loss: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 13255/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 0.0312 - val_loss: 0.0952 - val_accuracy: 0.0000e+00
# Epoch 13256/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.0312 - val_loss: 0.0884 - val_accuracy: 0.0000e+00
# Epoch 13257/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0312 - val_loss: 0.0863 - val_accuracy: 0.0000e+00
# Epoch 13258/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 13259/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.0312 - val_loss: 0.0896 - val_accuracy: 0.0000e+00
# Epoch 13260/20000
# 1/7 [===>..........................] - ETA: 0s - loss: 1.6315e-04 - accuracy: 0.0000e+00
# KeyboardInterrupt

# %% [markdown]
# #### Visualize the Overfit
#
# Now we can visualize our overfit model.

# %%
pred_norm_Nporsity = model_3(tf.convert_to_tensor(norm_depth_bins.reshape([-1,1]))).numpy().flatten() # predict with our ANN
pred_Nporosity = ((pred_norm_Nporsity + 1)/2*(Npor_max - Npor_min)+Npor_min)

plt.subplot(1,1,1)
plt.plot(depth_bins,pred_Nporosity,'black',linewidth=2)
plt.plot(X2_train['Depth'].values,y2_train['Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=1.0, label = "Train")
plt.plot(X2_test['Depth'].values,y2_test['Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=1.0, label = "Test")
plt.xlabel('Depth (m)')
plt.ylabel('Porosity (faction)')
plt.legend()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# #### Visualize the Training and Testing Error
#
# Let's visualize the training and testing error over the training epochs.

# %%
# Plot the Loss vs. Training Epoch 
plt.subplot(1,1,1)
plt.plot(hist3.history['loss'])
plt.plot(hist3.history['val_loss'])
plt.title('Loss function of Artificial Neural Net Example #2')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0,0.4)
plt.grid()
plt.tight_layout()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# We can observe the weights and bias terms associate with our neural network.
#
# #### Comments
#
# This was a basic demonstration of artificial neural networks.
#
# The Texas Center for Geostatistics has many other demonstrations on the basics of working with DataFrames, ndarrays, univariate statistics, plotting data, declustering, data transformations, trend modeling and many other workflows available [here](https://github.com/GeostatsGuy/PythonNumericalDemos), along with a package for geostatistics in Python called [GeostatsPy](https://github.com/GeostatsGuy/GeostatsPy).
#
# We hope this was helpful,
#
# *Michael* and *Honggeun*
#
# ***
#
# #### More on Michael Pyrcz and the Texas Center for Data Analytics and Geostatistics:
#
# ### Michael Pyrcz, Associate Professor, University of Texas at Austin
# *Novel Data Analytics, Geostatistics and Machine Learning Subsurface Solutions*
#
# With over 17 years of experience in subsurface consulting, research and development, Michael has returned to academia driven by his passion for teaching and enthusiasm for enhancing engineers' and geoscientists' impact in subsurface resource development.
#
# For more about Michael check out these links:
#
# #### [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
#
# #### Want to Work Together?
#
# I hope this content is helpful to those that want to learn more about subsurface modeling, data analytics and machine learning. Students and working professionals are welcome to participate.
#
# * Want to invite me to visit your company for training, mentoring, project review, workflow design and / or consulting? I'd be happy to drop by and work with you!
#
# * Interested in partnering, supporting my graduate student research or my Subsurface Data Analytics and Machine Learning consortium (co-PIs including Profs. Foster, Torres-Verdin and van Oort)? My research combines data analytics, stochastic modeling and machine learning theory with practice to develop novel methods and workflows to add value. We are solving challenging subsurface problems!
#
# * I can be reached at mpyrcz@austin.utexas.edu.
#
# I'm always happy to discuss,
#
# *Michael*
#
# Michael Pyrcz, Ph.D., P.Eng. Associate Professor The Hildebrand Department of Petroleum and Geosystems Engineering, Bureau of Economic Geology, The Jackson School of Geosciences, The University of Texas at Austin
#
# #### More Resources Available at: [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
